# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
df = pd.read_csv("./Data/housing.csv", header=None, delimiter=r"\s+",names = column_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
data_null = pd.DataFrame({"Null count":df.isnull().sum(),"Ratio null":df.isnull().sum()/len(df)})
data_null.drop('MEDV')
data_null.sort_values('Ratio null')
# Out:
#          Null count  Ratio null
# CRIM              0         0.0
# ZN                0         0.0
# INDUS             0         0.0
# CHAS              0         0.0
# NOX               0         0.0
# RM                0         0.0
# AGE               0         0.0
# DIS               0         0.0
# RAD               0         0.0
# TAX               0         0.0
# PTRATIO           0         0.0
# B                 0         0.0
# LSTAT             0         0.0
# MEDV              0         0.0

# %%
data = df.copy()
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
features_numerical = df.select_dtypes(exclude = ['object']).drop(['MEDV'], axis = 1).copy()
features_numerical.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
features_categorical = df.select_dtypes(include = ['object']).copy()
features_categorical.columns
# Out:
# Index([], dtype='object')

# %%
fig = plt.figure(figsize = (20,25))
sns.set(style = 'darkgrid')
for i in range(len(features_numerical.columns)):
    fig.add_subplot(5, 3, i+1)
    sns.distplot(features_numerical.iloc[:,i].dropna(), hist = True, color = 'b')
    plt.xlabel(features_numerical.columns[i])
plt.tight_layout()
# Out:
# d:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# d:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# d:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
features_numerical
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
fig = plt.figure(figsize = (20,25))
sns.set(style = 'darkgrid')
for i in range(len(features_numerical.columns)):
    fig.add_subplot(5, 3, i+1)
    sns.boxplot(y = features_numerical.iloc[:,i].dropna())
plt.tight_layout()

# %%
fig = plt.figure(figsize = (20,25))
sns.set(style = 'whitegrid')
for i in range(len(features_numerical.columns)):
    fig.add_subplot(5, 3, i+1)
    sns.scatterplot(features_numerical.iloc[:,i].dropna(), df["MEDV"])
plt.tight_layout()
# Out:
# d:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.subplots(figsize = (10, 10))
sns.heatmap(df.corr()[['MEDV']].abs().sort_values(by = "MEDV", ascending=False), annot = True)
plt.show()

# %%
#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score, r2_score, mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score
#Model Selection
from sklearn.model_selection import KFold,train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# Normalize
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop(['MEDV'],axis=1),data['MEDV'],test_size=0.2,random_state=2)

# %%
## Feature selection 
from sklearn.feature_selection import f_regression
f_val ,p_val = f_regression(X_train.copy(),y_train.copy())

# %%
plt.bar(data.drop(['MEDV'],axis=1).columns,f_val)
plt.xticks(rotation = 90)
plt.show()

# %%
#linear regression 

linear = LinearRegression()
linear.fit(X_train,y_train)
y_pred = linear.predict(X_test)

#R2 score 
print("R2_score: {}".format(r2_score(y_pred, y_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_pred, y_test)))
# Out:
# R2_score: 0.757930066048379
# Mean square error: 18.49542012244836

# %%
rf = RandomForestRegressor(n_estimators=100,random_state=0)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
#R2 score 
print("R2_score: {}".format(r2_score(y_pred, y_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_pred, y_test)))
# Out:
# R2_score: 0.8688509305240666
# Mean square error: 9.555939970588232

# %%
# su dung feature selection

# %%
X_v2_train = X_train[["LSTAT", "RM", "INDUS", "PTRATIO", "TAX", "NOX"]]
y_v2_train = y_train.copy()
X_v2_test = X_test[["LSTAT", "RM", "INDUS", "PTRATIO", "TAX", "NOX"]]
y_v2_test = y_test.copy()

# %%
linear2 = LinearRegression()
linear2.fit(X_v2_train, y_v2_train)

y_v2_pred = linear2.predict(X_v2_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_v2_pred, y_v2_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_v2_pred, y_v2_test)))
# Out:
# R2_score: 0.7254793162466233
# Mean square error: 20.06952273634619

# %%
rf2 = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf2.fit(X_v2_train, y_v2_train)

y_v2_pred = rf2.predict(X_v2_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_v2_pred, y_v2_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_v2_pred, y_v2_test)))
# Out:
# R2_score: 0.8934816081513467
# Mean square error: 7.724754686274507

# %%
##Normalize

# %%
scaler = RobustScaler()
transform = scaler.fit(data.copy())
data2 = transform.transform(data)
data2
# Out:
# array([[-0.06959315,  1.44      , -0.57164988, ...,  0.26190191,
#         -0.63768116,  0.35109718],
#        [-0.06375455,  0.        , -0.20294345, ...,  0.26190191,
#         -0.22188906,  0.05015674],
#        [-0.06376011,  0.        , -0.20294345, ...,  0.06667466,
#         -0.73263368,  1.69278997],
#        ...,
#        [-0.05445006,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.57171414,  0.33855799],
#        [-0.04086745,  0.        ,  0.17350891, ...,  0.09641444,
#         -0.48775612,  0.10031348],
#        [-0.05816351,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.34782609, -1.1661442 ]])

# %%
X_n_train, X_n_test, y_n_train, y_n_test = train_test_split(data2[:,:-1], data2[:,-1], test_size = 0.2, random_state = 2)

# %%
rf3 = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf3.fit(X_n_train, y_n_train)

y_n_pred = rf3.predict(X_n_test)
y_nn_pred = rf3.predict(X_n_train)

# R2_score 
print("R2_score: {}".format(r2_score(y_n_pred, y_n_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n_pred, y_n_test)))
r2_score(y_nn_pred, y_n_train)
# Out:
# R2_score: 0.8691288751192452
# Mean square error: 0.14991452813984932
# 0.9802386853070115

# %%
linear3 = LinearRegression()
linear3.fit(X_n_train, y_n_train)

y_n_pred = linear3.predict(X_n_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_n_pred, y_n_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n_pred, y_n_test)))
# Out:
# R2_score: 0.7579300660483783
# Mean square error: 0.29080563473155135

# %%
#chuan hoa + lua chon dac trung 
data3 = data[["LSTAT", "RM", "INDUS", "PTRATIO", "TAX", "NOX"]]

# %%
scaler = RobustScaler()
transform = scaler.fit(data3.copy())
data4 = transform.transform(data3)
data4
# Out:
# array([[-0.63768116,  0.49661247, -0.57164988, -1.33928571, -0.0878553 ,
#          0.        ],
#        [-0.22188906,  0.28794038, -0.20294345, -0.44642857, -0.22739018,
#         -0.39428571],
#        [-0.73263368,  1.32317073, -0.20294345, -0.44642857, -0.22739018,
#         -0.39428571],
#        ...,
#        [-0.57171414,  1.0399729 ,  0.17350891,  0.69642857, -0.14728682,
#          0.2       ],
#        [-0.48775612,  0.79336043,  0.17350891,  0.69642857, -0.14728682,
#          0.2       ],
#        [-0.34782609, -0.24186992,  0.17350891,  0.69642857, -0.14728682,
#          0.2       ]])

# %%
X_n1_train, X_n1_test, y_n1_train, y_n1_test = train_test_split(data4[:,:-1], data4[:,-1], test_size = 0.2, random_state = 2)

# %%
rf4 = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf4.fit(X_n1_train, y_n1_train)

y_n1_pred = rf4.predict(X_n1_test)
y_nn1_pred = rf4.predict(X_n1_train)

# R2_score 
print("R2_score: {}".format(r2_score(y_n1_pred, y_n1_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n1_pred, y_n1_test)))
r2_score(y_nn1_pred, y_n1_train)
# Out:
# R2_score: 0.8499233729179866
# Mean square error: 0.05077117897751096
# 0.973757239099558

# %%
linear4 = LinearRegression()
linear4.fit(X_n1_train, y_n1_train)

y_n1_pred = linear4.predict(X_n1_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_n1_pred, y_n1_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n1_pred, y_n1_test)))
# Out:
# R2_score: 0.4367954231206237
# Mean square error: 0.16002195042469447
